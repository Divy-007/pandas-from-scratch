# %% [markdown]
# # diffrent chart titles

# %%
import pandas as pd
import matplotlib as plt
# plt.style.use("fivethirtyeight")

# %%
oil = pd.read_csv(r"F:\coding\pandas-from-scratch\notebooks\Sec-5_DataVisualization\oil.csv")
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.astype({"date":"datetime64"}).set_index("date").loc["2014"].plot(
    title="oil per barrel price",
    xlabel="year",
    ylabel="oil_price",
    # color="#4e351f",
    cmap="Pastel2",
    style=".-",
    grid=True,
    figsize=(6,6)
).legend(bbox_to_anchor=(1.2,1.2));
