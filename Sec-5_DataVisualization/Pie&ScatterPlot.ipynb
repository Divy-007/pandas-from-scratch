# %% [markdown]
# # pie charts and scatterplots

# %%
import pandas as pd

# %%
oil = pd.read_csv(r"F:\coding\pandas-from-scratch\notebooks\Sec-5_DataVisualization\oil.csv")
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil.loc[oil["dcoilwtico"] >108,"dcoilwtico" ].plot.pie(title="oil price grater then 109", ylabel="price",startangle=90);

# %%
oil.loc[oil["dcoilwtico"] >100 ].plot.scatter(x="date",y="dcoilwtico");
